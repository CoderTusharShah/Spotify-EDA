# %% [markdown]
# # Spotify Dataset Analysis
#
# ***

# %% [markdown]
# ## Importing Dataset & Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
spotify_df = pd.read_csv("C:/Users/HP/Jupyter/Spotify Analysis/spotify_artist_data.csv")
spotify = spotify_df.copy()

# %% [markdown]
# Some basic settings for Visualization

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ***

# %% [markdown]
# ## Data Preprocess & Cleaning

# %%
spotify
# Out:
#       Unnamed: 0    Artist Name    Lead Streams           Feats Tracks  \
# 0              1          Drake  50,162,292,808  19,246,513,666    262
# 1              2      Bad Bunny  44,369,032,140   5,391,990,975    163
# 2              3     Ed Sheeran  38,153,682,361   2,791,278,201    240
# 3              4     The Weeknd  34,767,779,741   4,288,903,657    186
# 4              5   Taylor Swift  32,596,728,109     424,053,296    323
# ...          ...            ...             ...             ...    ...
# 1004        1005          Gotye   1,424,591,618      10,576,378     46
# 1005        1006           NIKI   1,422,920,850     231,405,433     55
# 1006        1007    Duke Dumont   1,422,096,182      24,622,115    121
# 1007        1008  Laura Pausini   1,421,622,604     293,291,443    434
# 1008        1009           Beck   1,420,597,420      83,871,063    300
#
#      One Billion 100 Million Last Updated
# 0              6         130     19.09.22
# ...

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1009 non-null   int64
#  1   Artist Name   1009 non-null   object
#  2   Lead Streams  1009 non-null   object
#  3   Feats         1009 non-null   object
#  4   Tracks        1009 non-null   object
#  5   One Billion   1009 non-null   object
#  6   100 Million   1009 non-null   object
#  7   Last Updated  1009 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 63.2+ KB

# %% [markdown]
# #### Checking for Null Values
# This dataset does not contain any null values which saves lot of work

# %%
spotify.isnull().sum()
# Out:
# Unnamed: 0      0
# Artist Name     0
# Lead Streams    0
# Feats           0
# Tracks          0
# One Billion     0
# 100 Million     0
# Last Updated    0
# dtype: int64

# %% [markdown]
# #### Removing errors from the column
# - Dropping column 'Unamed: 0' as it is unecessary
# - Dropping duplicates entry from the dataset
# - Removing Tracks from Tracks column

# %%
spotify.columns
# Out:
# Index(['Unnamed: 0', 'Artist Name', 'Lead Streams', 'Feats', 'Tracks',
#        'One Billion', '100 Million', 'Last Updated'],
#       dtype='object')

# %%
spotify.drop( columns = 'Unnamed: 0' , axis = 1 , inplace = True)

# %%
len(spotify['Artist Name'].unique())
# Out:
# 1001

# %% [markdown]
# Checking for the duplicates

# %%
duplicate = spotify[spotify.duplicated()]
duplicate
# Out:
#     Artist Name  Lead Streams  Feats  Tracks One Billion 100 Million  \
# 201      Artist  Lead Streams  Feats  Tracks          1b        100m
# 302      Artist  Lead Streams  Feats  Tracks          1b        100m
# 403      Artist  Lead Streams  Feats  Tracks          1b        100m
# 504      Artist  Lead Streams  Feats  Tracks          1b        100m
# 605      Artist  Lead Streams  Feats  Tracks          1b        100m
# 706      Artist  Lead Streams  Feats  Tracks          1b        100m
# 807      Artist  Lead Streams  Feats  Tracks          1b        100m
# 908      Artist  Lead Streams  Feats  Tracks          1b        100m
#
#     Last Updated
# 201       Update
# 302       Update
# 403       Update
# 504       Update
# 605       Update
# 706       Update
# 807       Update
# 908       Update

# %%
spotify.drop_duplicates(inplace = True)

# %%
spotify.shape
# Out:
# (1001, 7)

# %%
spotify['Lead Streams'].unique()
# Out:
# array(['50,162,292,808', '44,369,032,140', '38,153,682,361', ...,
#        '1,422,096,182', '1,421,622,604', '1,420,597,420'], dtype=object)

# %%
spotify['Feats'].unique()
# Out:
# array(['19,246,513,666', '5,391,990,975', '2,791,278,201',
#        '4,288,903,657', '424,053,296', '10,816,202,075', '2,052,297,828',
#        '4,165,031,640', '2,728,018,288', '323,205,288', '9,950,347,777',
#        '5,767,153,127', '0', '3,751,941,085', '349,750,231', '65,400,698',
#        '2,664,663,104', '7,514,655,612', '2,923,419,376', '6,677,097,087',
#        '9,662,107,113', '18,447', '1,131,603,410', '46,809,153',
#        '3,874,562,483', '5,656,394,885', '419,338,360', '8,647,763,108',
#        '277,349,953', '35,125,587', '1,949,901,038', '74,107,163',
#        '9,255,946,718', '400,919,869', '7,787,759,348', '94,739,265',
#        '3,309,086,106', '10,558,501,637', '4,592,555,695',
#        '2,459,831,429', '2,075,330,489', '3,054,317,056', '7,414,576,492',
#        '641,714,533', '8,235,141,311', '47,851,519', '1,924,490,635',
#        '1,217,714,183', '1,133,263,396', '456,987,347', '801,314,209',
# ...

# %%
spotify['Tracks'].unique()
# Out:
# array(['262', '163', '240', '186', '323', '225', '181', '301', '98',
#        '242', '239', '65', '116', '299', '198', '189', '144', '215',
#        '119', '278', '113', '705', '126', '81', '360', '238', '121',
#        '145', '557', '366', '71', '504', '124', '197', '427', '314',
#        '137', '171', '160', '180', '792', '140', '195', '39', '350', '90',
#        '182', '107', '248', '166', '343', '85', '61', '134', '266', '232',
#        '251', '167', '220', '327', '168', '109', '394', '199', '157',
#        '162', '221', '146', '99', '70', '123', '476', '37', '814', '224',
#        '34', '269', '170', '461', '104', '397', '936', '313', '227',
#        '208', '193', 'Tracks', '283', '178', '303', '147', '205', '103',
#        '142', '108', '243', '154', '45', '416', '653', '165', '138',
#        '139', '374', '347', '49', '312', '118', '172', '618', '141',
#        '213', '136', '48', '176', '306', '122', '175', '282', '768',
# ...

# %%
spotify.drop( spotify[spotify.Tracks == 'Tracks'].index , inplace = True)

# %%
spotify['One Billion'].unique()
# Out:
# array(['6', '5', '10', '8', '1', '9', '3', '4', '7', '2', '0'],
#       dtype=object)

# %%
spotify['100 Million'].unique()
# Out:
# array(['130', '118', '62', '72', '96', '58', '71', '65', '57', '98', '66',
#        '63', '47', '60', '34', '36', '41', '44', '51', '40', '46', '49',
#        '31', '32', '29', '24', '28', '45', '27', '38', '39', '35', '26',
#        '19', '33', '30', '18', '37', '25', '17', '23', '21', '14', '20',
#        '13', '16', '11', '10', '15', '8', '22', '12', '9', '5', '7', '4',
#        '6', '0', '3', '2', '1'], dtype=object)

# %%
spotify['Last Updated'].unique()
# Out:
# array(['19.09.22', '20.09.22', '18.09.22', '17.09.22', '15.09.22',
#        '06.09.22', '16.09.22', '03.09.22', '13.09.22', '12.09.22',
#        '18.08.22', '09.09.22', '31.07.22', '08.09.22', '28.08.22',
#        '10.09.22', '25.08.22', '05.09.22', '01.09.22', '11.09.22',
#        '14.09.22', '12.08.22', '21.08.22', '04.09.22', '02.09.22',
#        '29.08.22', '22.08.22', '31.08.22', '11.08.22', '20.08.22',
#        '05.08.22', '26.08.22', '24.08.22', '14.08.22', '17.08.22',
#        '07.09.22', '27.08.22', '19.08.22', '23.08.22', '13.08.22',
#        '09.08.22', '07.08.22', '01.08.22', '16.08.22', '03.08.22',
#        '10.08.22', '06.08.22', '08.07.22', '15.08.22', '30.08.22',
#        '08.08.22', '30.06.22', '06.08.21'], dtype=object)

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Artist Name   1000 non-null   object
#  1   Lead Streams  1000 non-null   object
#  2   Feats         1000 non-null   object
#  3   Tracks        1000 non-null   object
#  4   One Billion   1000 non-null   object
#  5   100 Million   1000 non-null   object
#  6   Last Updated  1000 non-null   object
# dtypes: object(7)
# memory usage: 62.5+ KB

# %% [markdown]
# #### Checking for column data types
#
# - Removing ' , ' from the numeric data
# - Typecasting columns like One Biillion 100 Million , Tracks into int64

# %%
spotify.columns
# Out:
# Index(['Artist Name', 'Lead Streams', 'Feats', 'Tracks', 'One Billion',
#        '100 Million', 'Last Updated'],
#       dtype='object')

# %%
spotify.dtypes
# Out:
# Artist Name     object
# Lead Streams    object
# Feats           object
# Tracks          object
# One Billion     object
# 100 Million     object
# Last Updated    object
# dtype: object

# %% [markdown]
# Before TypeCasting into integer first we have to remove ',' value from the number

# %%
spotify['Lead Streams'] = spotify['Lead Streams'].str.replace(',','')
spotify['Feats'] = spotify['Feats'].str.replace(',','')
spotify['Tracks'] = spotify['Tracks'].str.replace(',','')

# %%
spotify['Lead Streams'] = spotify['Lead Streams'].astype(float)
spotify['Feats'] = spotify['Feats'].astype(float)
spotify['Tracks'] = spotify['Tracks'].astype(float)
spotify['One Billion'] = spotify['One Billion'].astype(float)
spotify['100 Million'] = spotify['100 Million'].astype(float)

# %%
spotify['Last Updated'] = pd.to_datetime(spotify['Last Updated'])

# %%
spotify.dtypes
# Out:
# Artist Name             object
# Lead Streams           float64
# Feats                  float64
# Tracks                 float64
# One Billion            float64
# 100 Million            float64
# Last Updated    datetime64[ns]
# dtype: object

# %%
spotify.describe()
# Out:
#        Lead Streams         Feats        Tracks  One Billion  100 Million
# count  1.000000e+03  1.000000e+03   1000.000000  1000.000000  1000.000000
# mean   4.291403e+09  8.619085e+08    267.901000     0.360000     8.977000
# std    4.827224e+09  1.742020e+09    620.636208     1.047615    11.443226
# min    1.420597e+09  0.000000e+00     11.000000     0.000000     0.000000
# 25%    1.850499e+09  1.372302e+07     86.750000     0.000000     3.000000
# 50%    2.613283e+09  1.833078e+08    147.500000     0.000000     5.000000
# 75%    4.625016e+09  7.977515e+08    252.250000     0.000000    10.000000
# max    5.016229e+10  1.924651e+10  11475.000000    10.000000   130.000000

# %% [markdown]
# ***

# %% [markdown]
# ## Exploratory Analysis & Visualization
# We will Analyse all the columns & tries to find the relation between them

# %%
spotify.columns
# Out:
# Index(['Artist Name', 'Lead Streams', 'Feats', 'Tracks', 'One Billion',
#        '100 Million', 'Last Updated'],
#       dtype='object')

# %% [markdown]
# ### Artist
# Top 20 Artists by Lead Stream

# %%
top20_lead_stream = spotify.sort_values(by=['Lead Streams'] , ascending = False).head(20)
top20_lead_stream
# Out:
#         Artist Name  Lead Streams         Feats  Tracks  One Billion  \
# 0             Drake  5.016229e+10  1.924651e+10   262.0          6.0
# 1         Bad Bunny  4.436903e+10  5.391991e+09   163.0          5.0
# 2        Ed Sheeran  3.815368e+10  2.791278e+09   240.0         10.0
# 3        The Weeknd  3.476778e+10  4.288904e+09   186.0          8.0
# 4      Taylor Swift  3.259673e+10  4.240533e+08   323.0          1.0
# 5     Justin Bieber  3.246600e+10  1.081620e+10   225.0          6.0
# 6     Ariana Grande  3.228768e+10  2.052298e+09   181.0          8.0
# 7            Eminem  3.043186e+10  4.165032e+09   301.0          5.0
# 8       Post Malone  2.983228e+10  2.728018e+09    98.0          9.0
# 9               BTS  2.853346e+10  3.232053e+08   262.0          1.0
# 10         J Balvin  2.589219e+10  9.950348e+09   242.0          3.0
# 11       Kanye West  2.553512e+10  5.767153e+09   239.0          1.0
# 12    Billie Eilish  2.368499e+10  0.000000e+00    65.0          4.0
# ...

# %%
plt.bar(top20_lead_stream['Artist Name'],top20_lead_stream['Lead Streams'])
plt.xticks(rotation=75)
plt.xlabel('Artists')
plt.ylabel('Lead Streams')
plt.title('Top 20 Artist by Lead Streams')
# Out:
# Text(0.5, 1.0, 'Top 20 Artist by Lead Streams')

# %%
sns.barplot(x='Lead Streams' , y = 'Artist Name' , data=top20_lead_stream)
# Out:
# <AxesSubplot:xlabel='Lead Streams', ylabel='Artist Name'>

# %% [markdown]
# Top 20 Artist by 100 Million

# %%
top20_million = spotify.sort_values(by=['100 Million'] , ascending = False).head(20)
top20_million
# Out:
#       Artist Name  Lead Streams         Feats  Tracks  One Billion  \
# 0           Drake  5.016229e+10  1.924651e+10   262.0          6.0
# 1       Bad Bunny  4.436903e+10  5.391991e+09   163.0          5.0
# 9             BTS  2.853346e+10  3.232053e+08   262.0          1.0
# 4    Taylor Swift  3.259673e+10  4.240533e+08   323.0          1.0
# 3      The Weeknd  3.476778e+10  4.288904e+09   186.0          8.0
# 6   Ariana Grande  3.228768e+10  2.052298e+09   181.0          8.0
# 10       J Balvin  2.589219e+10  9.950348e+09   242.0          3.0
# 7          Eminem  3.043186e+10  4.165032e+09   301.0          5.0
# 11     Kanye West  2.553512e+10  5.767153e+09   239.0          1.0
# 2      Ed Sheeran  3.815368e+10  2.791278e+09   240.0         10.0
# 13     Juice WRLD  2.311407e+10  3.751941e+09   116.0          3.0
# 5   Justin Bieber  3.246600e+10  1.081620e+10   225.0          6.0
# 8     Post Malone  2.983228e+10  2.728018e+09    98.0          9.0
# ...

# %%
plt.bar(top20_million['Artist Name'],top20_million['100 Million'])
plt.xticks(rotation=75)
plt.xlabel('Artists')
plt.ylabel('100 Million')
plt.title('Top 20 Artist by 100 Million');

# %%
sns.barplot(x='100 Million' , y = 'Artist Name' , data=top20_lead_stream)
# Out:
# <AxesSubplot:xlabel='100 Million', ylabel='Artist Name'>

# %% [markdown]
# We can see a positive relation between Lead Streams & Million , Artists having more Lead stream tend to have more number of million

# %%
top20_billion = spotify.sort_values(by=['One Billion'] , ascending = False).head(20)
top20_billion
# Out:
#       Artist Name  Lead Streams         Feats  Tracks  One Billion  \
# 2      Ed Sheeran  3.815368e+10  2.791278e+09   240.0         10.0
# 8     Post Malone  2.983228e+10  2.728018e+09    98.0          9.0
# 3      The Weeknd  3.476778e+10  4.288904e+09   186.0          8.0
# 6   Ariana Grande  3.228768e+10  2.052298e+09   181.0          8.0
# 22       Maroon 5  1.995257e+10  1.844700e+04   240.0          7.0
# 19         Khalid  2.097374e+10  2.923419e+09   119.0          7.0
# 17   XXXTENTACION  2.172680e+10  2.664663e+09   144.0          7.0
# 15       Dua Lipa  2.218629e+10  3.497502e+08   198.0          7.0
# 0           Drake  5.016229e+10  1.924651e+10   262.0          6.0
# 5   Justin Bieber  3.246600e+10  1.081620e+10   225.0          6.0
# 14       Coldplay  2.221484e+10  0.000000e+00   299.0          5.0
# 1       Bad Bunny  4.436903e+10  5.391991e+09   163.0          5.0
# 32          Adele  1.556122e+10  7.410716e+07    71.0          5.0
# ...

# %%
plt.bar(top20_billion['Artist Name'] , top20_billion['One Billion'])
plt.xticks(rotation = 75)
plt.xlabel('Artist Name')
plt.ylabel('Number of Billions')
plt.title('Top 20 Artisit by Number of Billions')
plt.show()

# %%
sns.barplot(x='One Billion' , y = 'Artist Name' , data = top20_billion);

# %% [markdown]
# Now , if we see that plot for Number of Billions we observe that the trends changes a little bits. So , More Lead Streams is not equavalent to more number of billions

# %% [markdown]
# ### Tracks
# Does more number of tracks ensure more 100 Million or 1 Billion?

# %%
plt.scatter(spotify.Tracks , spotify['100 Million'])
plt.ylabel('100 Million')
plt.xlabel('Number of Tracks')
plt.title('Relation of Track with 100 Million')
plt.show()

# %%
sns.scatterplot(x='Tracks',y='100 Million' , data=spotify , s=60)
plt.title('Relation of Track with 100 Million');

# %% [markdown]
# ***

# %% [markdown]
# ## Ask Questions & Answer ( Covered Above)
# Which artist has highest number of Lead Streams?
#
# Does Number of tracks has any relationship with views?
#
# Trend between Lead Stream , 100 Million & Billion

# %% [markdown]
# ***

# %% [markdown]
# ## Summary & Conclusiom
# We can see the artist with more Lead Streams has more 100 Million but that is not true for Billion. Also more tracks does not ensure more Lead Streams or 100 Million or 1 Billion.

# %% [markdown]
# ***

# %% [markdown]
# ## Problem Faces
#
# - Encountring  ','  in the numeric values
# - When Typecasting into int facing overflow error as value exceded sys default int size

# %% [markdown]
# ***
